# %%
import numpy as np
import sys

# %%
# Testing out the random number generators
np.random.randint(0,101) # gerate a number from 0-100
np.random.randint(0,11) # generate a number fom 0-10

# %%
# Testing Guess value
guess = 2
guess_strformat = str(guess)
print(type(guess_strformat))
print(guess_strformat)

# %%
# # store a random number
# computer_stored_value = []
# value = np.random.randint(0,11)
# value_strformat = str(value)
# computer_stored_value.append(value_strformat)
# print(computer_stored_value)
# print(type(computer_stored_value[0]))

# In Jupyter this block will generate a new number each time it is run
# Out:
# ['3']
# <class 'str'>

# %%
# # Statements 
# introduction = f" \t\t\t~ Welcome to the Guessing Game ~ \n"
# introduction += f'\t\tI will choose a number at random, and you will guess!'

# rules = f'NICE!\n'
# rules += f'Alrighty, I will pick a number between 0 and 10 inclusive.\n'
# rules += f'If at anypoint you want to give up just type: quit\n'
# rules += f'Now, what is your guess?'

# correct = f"Congrats! You guessed my number! : {computer_stored_value[0]}"
# incorrect = f"{guess} is not my number. Try again."
# incorrect1 = f"Nope! {guess} is not my number. Try agian."
# incorrect2 = f"Woah, not even close! {incorrect}"
# incorrect3 = f"Seems like this game might be too difficult for you? {incorrect}"
# incorrect4 = f"Still no luck. {incorrect}"

# fails = [incorrect, incorrect1, incorrect2, incorrect3, incorrect4]

# Exit_by_quiting = f'Want to give up?\nType: quit'
# Exit_by_nonplay = f'Do you wish to play? (Y/N)'

# goodbye = f'Game Terminated. See you next time!'

# print(rules)
# print(fails[4])
# print(correct)
# print(introduction)
# print(Exit_by_quiting)
# print(Exit_by_nonplay)
# print(goodbye)

# %%
# Comparison tests & statement returns 

if guess_strformat == computer_stored_value[0]: 
    print(correct)
elif guess_strformat != computer_stored_value[0]:
    print(fails[np.random.randint(0,5)])

# %%
# While loop to keep game running until quit is called
# consider makeing it easier on the user to put any type of format for quit 
#  this means like having accidental spaces or capitals 

# input() will always return a string

# Introduce the game



status = 'ON'

while status != 'quit': 
    # Introduction Statements
    print(introduction)
    # Ask for play
    print(Exit_by_nonplay)
    # Take input
    ask_for_input = input()

    #Check input
    if ask_for_input == "N":
        #Leave the Game
        print(ask_for_input)
        status = 'quit'

    elif ask_for_input == "Y": 
        # continue game 
        print(ask_for_input)
        print(rules)
        ask_for_number = input()
        print(ask_for_number)
        if ask_for_number == computer_stored_value[0]: 
            print(correct)
        elif ask_for_number == "quit":
            status = 'quit'
        else:
            print(fails[np.random.randint(0,5)])


print(goodbye)

# %%
# Now that the game runs add the mechanics prior to the while loop to call them 

#Packages 
import numpy as np
import sys

#Initial Statements
 
introduction = f" \t\t\t~ Welcome to the Guessing Game ~ \n"
introduction += f'\t\tI will choose a number at random, and you will guess!'

rules_and_initial_ask = f'\nNICE!'
rules_and_initial_ask += f'\nAlrighty, I will pick a number between 0 and 10 inclusive.\n'
rules_and_initial_ask += f'If at anypoint you want to give up just type: quit'
rules_and_initial_ask += f'\n\nNow, what is your guess?'

#Exit Statements
Exit_by_quiting = f'Want to give up?\nType: quit'
Exit_by_nonplay = f'Do you wish to play? (Y/N)'
goodbye = f'Game Terminated. See you next time!'




# initiate the game
print(introduction)
status = 'ON'

while status != 'quit': 

    # Ask the user to play with Rule statement -(Y/N)
    print(Exit_by_nonplay)
    # Take input
    condition_to_play = input("Type: (Y/N)  ").upper()

    #Check input to continue game
    if condition_to_play == "N":
        #Leave the Game
        print(condition_to_play)
        status = 'quit'

    elif condition_to_play == "Y": 
        # continue game 
        print(condition_to_play) #prints Y

        #Tell the user how to play
        print(rules_and_initial_ask)
#-------------------------------------------------------------------------------------
        number_select = 'on'
        while number_select != 'off':

            #Computer selects a number
            computer_stored_value = []
            value = np.random.randint(0,11)
            value_strformat = str(value)
            computer_stored_value.append(value_strformat)

            #Delete once program is complete
            print(f'The stored number is: {computer_stored_value[0]}')

#-------------------------------------------------------------------------------------

            #Game questioning begins 
            answer = 'incorrect'
            while answer != 'correct':
                
                #Ask the user for a number
                ask_for_number = input('Guess a number between [0,10]:  ').lower()


                #Conditions
                if ask_for_number == "quit":
                    print(ask_for_number)
                    number_select = 'off'
                    answer = 'correct'

                elif ask_for_number == computer_stored_value[0]: 
                    print(ask_for_number)

                    #Congradualtion's Statement 
                    correct = f"Congrats! You guessed my number! : {computer_stored_value[0]}"
                    print(correct)

                    #Ask to play again
                    print('\nAnother round?')
                    condition_to_play_again = input("Type: (Y/N)  ").upper()

#-------------------------------------------------------------------------------------

                    play_again_question = 'active'
                    while play_again_question != 'completed':

                        if condition_to_play_again == 'N':
                            print(condition_to_play_again)
                            answer = 'correct'
                            number_select = 'off'
                            play_again_question ='completed'

                        elif condition_to_play_again == 'Y':
                            print(condition_to_play_again)
                            print('Ok! I thought of a new number.')
                            answer = 'correct'
                            play_again_question = 'completed'

                        else: 
                            print(condition_to_play_again)
                            print('That was not a valid entry.')
                            #should continue the loop

                    # number_select = 'off' #does this stay?
                    # answer = 'correct'
#-------------------------------------------------------------------------------------

                else:
                    #check if they gave a number 
                    is_this_a_number = ask_for_number.isdigit()
                    if is_this_a_number == True:
                        print(ask_for_number)
                        
                        #Statements for incorrect values
                        incorrect = f"{ask_for_number} is not my number. Try again."
                        incorrect1 = f"Nope! {ask_for_number} is not my number. Try agian."
                        incorrect2 = f"Woah, not even close! {incorrect}"
                        incorrect3 = f"Seems like this game might be too difficult for you? {incorrect}"
                        incorrect4 = f"Still no luck. {incorrect}"
                        fails_list = [incorrect, incorrect1, incorrect2, incorrect3, incorrect4]
                        print(fails_list[np.random.randint(0,5)])

                    elif is_this_a_number == False: 
                        print('This is not a valid entry. Try again')
#-------------------------------------------------------------------------------------
            # number_select = 'off'

        status = 'quit'
#-------------------------------------------------------------------------------------

    else: 
        print(condition_to_play)
        print('That was not a valid entry.')
        #While (status = quit) loop continues asking for a Y/N 


print(goodbye)
# Out:
#  			~ Welcome to the Guessing Game ~
# 		I will choose a number at random, and you will guess!
# Do you wish to play? (Y/N)
# Y
#
# NICE!
# Alrighty, I will pick a number between 0 and 10 inclusive.
# If at anypoint you want to give up just type: quit
#
# Now, what is your guess?
# The stored number is: 0
# 0
# Congrats! You guessed my number! : 0
#
# Another round?
# Y
# Ok! I thought of a new number.
# The stored number is: 9
# 8
# Woah, not even close! 8 is not my number. Try again.
# 9
# Congrats! You guessed my number! : 9
#
# Another round?
# N
# Game Terminated. See you next time!

# %%
# Convert input to integers
l = []

for i in range(0,2):
    text = input('say anything').upper()
    # number = int(text)
    # print(number)
    # l.append(number)
    # # print(type(text))
    # print(type(number))
    print(text)
    

print(l)
# Out:
# N
# N
# []

# %%
for i in range(0,2): 
    ask = input()
    compare = ask.isdigit()
    print(ask)
    if compare == True: 
        print('You gave me a number')
    elif compare == False: 
        print('You gave me not a number')
# Out:
# g
# You gave me not a number
# 5
# You gave me a number
